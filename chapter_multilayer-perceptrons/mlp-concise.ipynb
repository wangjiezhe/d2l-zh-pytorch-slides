# %% [markdown]
# # 多层感知机的简洁实现
#
# 通过高级API更简洁地实现多层感知机

# %%
import torch
from torch import nn
from d2l import torch as d2l

# %%
from d2l.torch import Accumulator, Animator, accuracy

def evaluate_accuracy(net, data_iter):
    """计算在指定数据集上模型的精度"""
    if isinstance(net, torch.nn.Module):
        net.eval()
    metric = Accumulator(2)
    with torch.no_grad():
        for X, y in data_iter:
            metric.add(accuracy(net(X), y), y.numel())
    return metric[0] / metric[1]

def train_epoch_ch3(net, train_iter, loss, updater):
    """训练模型一个迭代周期（定义见第3章）"""
    if isinstance(net, torch.nn.Module):
        net.train()
    metric = Accumulator(3)
    for X, y in train_iter:
        y_hat = net(X)
        l = loss(y_hat, y)
        if isinstance(updater, torch.optim.Optimizer):
            updater.zero_grad()
            l.mean().backward()
            updater.step()
        else:
            l.sum().backward()
            updater(X.shape[0])
        metric.add(float(l.sum()), accuracy(y_hat, y), y.numel())
    return metric[0] / metric[2], metric[1] / metric[2]

def train_ch3(net, train_iter, test_iter, loss, num_epochs, updater):
    """训练模型（定义见第3章）"""
    animator = Animator(xlabel='epoch', xlim=[1, num_epochs], ylim=[0.3, 0.9],
                        legend=['train loss', 'train acc', 'test acc'])
    for epoch in range(num_epochs):
        train_metrics = train_epoch_ch3(net, train_iter, loss, updater)
        test_acc = evaluate_accuracy(net, test_iter)
        animator.add(epoch + 1, train_metrics + (test_acc,))
    train_loss, train_acc = train_metrics
    assert train_loss < 0.5, train_loss
    assert train_acc <= 1 and train_acc > 0.7, train_acc
    assert test_acc <= 1 and test_acc > 0.7, test_acc

# %% [markdown]
# 隐藏层
# 包含256个隐藏单元，并使用了ReLU激活函数

# %%
net = nn.Sequential(nn.Flatten(),
                    nn.Linear(784, 256),
                    nn.ReLU(),
                    nn.Linear(256, 10))

def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, std=0.01)

net.apply(init_weights);

# %% [markdown]
# 训练过程

# %%
batch_size, lr, num_epochs = 256, 0.1, 10
loss = nn.CrossEntropyLoss(reduction='none')
trainer = torch.optim.SGD(net.parameters(), lr=lr)

train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)
train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)

# %%
evaluate_accuracy(net, test_iter)
# Out:
# 0.8357

# %% [markdown]
# ## 练习

# %% [markdown]
# 修改：2 层（256+64）

# %%
net = nn.Sequential(nn.Flatten(),
                    nn.Linear(784, 256),
                    nn.ReLU(),
                    nn.Linear(256, 64),
                    nn.ReLU(),
                    nn.Linear(64, 10))

def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, std=0.01)

net.apply(init_weights);

batch_size, lr, num_epochs = 256, 0.1, 10
loss = nn.CrossEntropyLoss(reduction='none')
trainer = torch.optim.SGD(net.parameters(), lr=lr)

train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)
train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)

# %%
evaluate_accuracy(net, test_iter)
# Out:
# 0.807

# %% [markdown]
# 修改：学习率为 0.5

# %%
net = nn.Sequential(nn.Flatten(),
                    nn.Linear(784, 256),
                    nn.ReLU(),
                    nn.Linear(256, 10))

def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, std=0.01)

net.apply(init_weights);

batch_size, lr, num_epochs = 256, 0.5, 10
loss = nn.CrossEntropyLoss(reduction='none')
trainer = torch.optim.SGD(net.parameters(), lr=lr)

train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)
train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)

# %%
evaluate_accuracy(net, test_iter)
# Out:
# 0.8604

# %% [markdown]
# 修改：激活函数改为 Parameterized ReLU

# %%
net = nn.Sequential(nn.Flatten(),
                    nn.Linear(784, 256),
                    nn.PReLU(),
                    nn.Linear(256, 10))

def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, std=0.01)

net.apply(init_weights);

batch_size, lr, num_epochs = 256, 0.1, 10
loss = nn.CrossEntropyLoss(reduction='none')
trainer = torch.optim.SGD(net.parameters(), lr=lr)

train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)
train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)

# %%
evaluate_accuracy(net, test_iter)
# Out:
# 0.8403

# %% [markdown]
# 修改：激活函数改为 Randomized ReLU

# %%
net = nn.Sequential(nn.Flatten(),
                    nn.Linear(784, 256),
                    nn.RReLU(),
                    nn.Linear(256, 10))

def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, std=0.01)

net.apply(init_weights);

batch_size, lr, num_epochs = 256, 0.1, 10
loss = nn.CrossEntropyLoss(reduction='none')
trainer = torch.optim.SGD(net.parameters(), lr=lr)

train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)
train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)

# %%
evaluate_accuracy(net, test_iter)
# Out:
# 0.8346

# %% [markdown]
# 修改：激活函数改为 ELU

# %%
net = nn.Sequential(nn.Flatten(),
                    nn.Linear(784, 256),
                    nn.ELU(),
                    nn.Linear(256, 10))

def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, std=0.01)

net.apply(init_weights);

batch_size, lr, num_epochs = 256, 0.1, 10
loss = nn.CrossEntropyLoss(reduction='none')
trainer = torch.optim.SGD(net.parameters(), lr=lr)

train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)
train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)

# %%
evaluate_accuracy(net, test_iter)
# Out:
# 0.8434

# %% [markdown]
# 修改：激活函数改为 SELU

# %%
net = nn.Sequential(nn.Flatten(),
                    nn.Linear(784, 256),
                    nn.SELU(),
                    nn.Linear(256, 10))

def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, std=0.01)

net.apply(init_weights);

batch_size, lr, num_epochs = 256, 0.1, 10
loss = nn.CrossEntropyLoss(reduction='none')
trainer = torch.optim.SGD(net.parameters(), lr=lr)

train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)
train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)

# %%
evaluate_accuracy(net, test_iter)
# Out:
# 0.8477

# %% [markdown]
# 修改：激活函数改为 Sigmoid

# %%
net = nn.Sequential(nn.Flatten(),
                    nn.Linear(784, 256),
                    nn.Sigmoid(),
                    nn.Linear(256, 10))

def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, std=0.01)

net.apply(init_weights);

batch_size, lr, num_epochs = 256, 0.1, 10
loss = nn.CrossEntropyLoss(reduction='none')
trainer = torch.optim.SGD(net.parameters(), lr=lr)

train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)
train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /root/d2l/d2l-zh-pytorch-slides/chapter_multilayer-perceptrons/mlp-concise.ipynb 单元格 29 line 1
#      <a href='vscode-notebook-cell://wsl%2Bgentoo/root/d2l/d2l-zh-pytorch-slides/chapter_multilayer-perceptrons/mlp-concise.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> trainer = torch.optim.SGD(net.parameters(), lr=lr)
#      <a href='vscode-notebook-cell://wsl%2Bgentoo/root/d2l/d2l-zh-pytorch-slides/chapter_multilayer-perceptrons/mlp-concise.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)
# ---> <a href='vscode-notebook-cell://wsl%2Bgentoo/root/d2l/d2l-zh-pytorch-slides/chapter_multilayer-perceptrons/mlp-concise.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)
#
# /root/d2l/d2l-zh-pytorch-slides/chapter_multilayer-perceptrons/mlp-concise.ipynb 单元格 29 line 4
#      <a href='vscode-notebook-cell://wsl%2Bgentoo/root/d2l/d2l-zh-pytorch-slides/chapter_multilayer-perceptrons/mlp-concise.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D?line=37'>38</a>     animator.add(epoch + 1, train_metrics + (test_acc,))
#      <a href='vscode-notebook-cell://wsl%2Bgentoo/root/d2l/d2l-zh-pytorch-slides/chapter_multilayer-perceptrons/mlp-concise.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D?line=38'>39</a> train_loss, train_acc = train_metrics
# ---> <a href='vscode-notebook-cell://wsl%2Bgentoo/root/d2l/d2l-zh-pytorch-slides/chapter_multilayer-perceptrons/mlp-concise.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D?line=39'>40</a> assert train_loss < 0.5, train_loss
#      <a href='vscode-notebook-cell://wsl%2Bgentoo/root/d2l/d2l-zh-pytorch-slides/chapter_multilayer-perceptrons/mlp-concise.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D?line=40'>41</a> assert train_acc <= 1 and train_acc > 0.7, train_acc
#      <a href='vscode-notebook-cell://wsl%2Bgentoo/root/d2l/d2l-zh-pytorch-slides/chapter_multilayer-perceptrons/mlp-concise.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D?line=41'>42</a> assert test_acc <= 1 and test_acc > 0.7, test_acc
#
# AssertionError: 0.5008627627690633

# %%
evaluate_accuracy(net, test_iter)
# Out:
# 0.8049

# %% [markdown]
# 修改：激活函数改为 Tanh

# %%
net = nn.Sequential(nn.Flatten(),
                    nn.Linear(784, 256),
                    nn.Tanh(),
                    nn.Linear(256, 10))

def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, std=0.01)

net.apply(init_weights);

batch_size, lr, num_epochs = 256, 0.1, 10
loss = nn.CrossEntropyLoss(reduction='none')
trainer = torch.optim.SGD(net.parameters(), lr=lr)

train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)
train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)

# %%
evaluate_accuracy(net, test_iter)
# Out:
# 0.8369
